# %% [markdown]
# ## 특징
#
# 1. 코드를 셀 단위로 작성 및 실행
# 1. 마크다운을 통한 문서화
# 1. 그래프나 표 등을 실시간으로 확인
# 1. html, pdf 등 파일로 저장

# %% [markdown]
# ![스크린샷 2024-07-08 오전 3.44.56.png](attachment:7f8005ae-7a49-4c22-9b6b-ec8784b72d37.png)

# %% [markdown]
# ## 사전 학습 자료
#
# 다음 링크에서 파이썬 기본편에 대한 학습을 하실 수 있습니다
# [혀누 블로그](https://hyunwooss.tistory.com)

# %%
# %%HTML
# <iframe width="640" height="360" src="https://www.youtube.com/embed/EQkxPps6K_E" title="전설의 현공면미, 이번엔 해적으로 모이다! [Sea of Thieves]" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>
# Out:
# <iframe width="640" height="360" src="https://www.youtube.com/embed/EQkxPps6K_E" title="전설의 현공면미, 이번엔 해적으로 모이다! [Sea of Thieves]" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

# %% [markdown]
# ## 파이썬 기본 문법

# %%
print("hello world")
print("안녕하세요")
# Out:
# hello world

# %%
for i in range(6):
    print("안녕하세요")
# Out:
# 안녕하세요
# 안녕하세요
# 안녕하세요
# 안녕하세요
# 안녕하세요
# 안녕하세요

# %%
print("환영합니다")
# Out:
# 환영합니다

# %%
name = "연탄이"
print(name)
# Out:
# 연탄이

# %%
print("Ctrl(command) + Enter : 현재 셀 실행 ")
# Out:
# Ctrl(command) + Enter : 현재 셀 실행

# %%
print("명령모드에서 a를 누르면 현재 셀 위에 새로운 셀 만들기 b누르면 현재 셀 아래에 만들기")
# Out:
# 명령모드에서 a를 누르면 현재 셀 위에 새로운 셀 만들기 b누르면 현재 셀 아래에 만들기

# %%
print("esc 누르면 명령모드")
# Out:
# esc 누르면 명령모드

# %%
print("Shift + Enter : 현재 셀 실행 후 다음 셀 선택")
# Out:
# Shift + Enter : 현재 셀 실행 후 다음 셀 선택

# %%
print("Alt(option) + Enter : 현재 셀 실행 후 다음 위치에 셀 삽입")
# Out:
# Alt(option) + Enter : 현재 셀 실행 후 다음 위치에 셀 삽입

# %% [markdown]
# ## 모듈 사용

# %%
import random
print(random.randint(1, 45))
# Out:
# 37

# %%
# random.randint?

# %%
# random.randint??

# %%
num = 3

# %%
num += 2

# %%
num += 4

# %%
print(num)
# Out:
# 9

# %% [markdown]
# ---
#
# ## 시각화 예제 1 : 그래프
#
# -matplotlib를 이용하면 다양한 그래프를 그릴 수 있으며 수행 결과를 바로 확인 할 수 있습니다

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots()             # Create a figure containing a single Axes.
ax.plot([1, 2, 3, 4], [1, 4, 2, 3])  # Plot some data on the Axes.
plt.show()                           # Show the figure.

# %% [markdown]
# ## 시각화 예재 2 : 테이블
#
# -pandas는 복잡한 데이터를 분석할 때 아주 유용합니다

# %%
import pandas as pd
pd.DataFrame({'A': [1, 2, 3]})
# Out:
#    A
# 0  1
# 1  2
# 2  3
